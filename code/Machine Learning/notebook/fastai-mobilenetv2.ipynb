# %%
from fastai.vision.all import *
from fastai.metrics import error_rate

# %%
df = '/kaggle/input/fruits/fruits-360-original-size/fruits-360-original-size/Training'

# %%
img_size = 224
batch_size = 32

# %%
train_transforms = aug_transforms(
    mult=1.0,
    do_flip=True,
    flip_vert=True,
    max_rotate=30,
    max_lighting=0.2,
    max_zoom=1.2,
    max_warp=0.2,
    p_affine=0.75,
    p_lighting=0.75,
    xtra_tfms=[RandomErasing(p=0.5, sh=0.1, min_aspect=0.2, max_count=2)]
)

# %%
test_transforms = Resize(img_size)

# %%
def get_image_files(path):
    return get_image_files(path, valid_extensions=['.jpg', '.jpeg', '.png'])

# %%
def label_func(file_path):
    return file_path.parent.name

# %%
train_data = ImageDataLoaders.from_folder(
    df,
    valid_pct=0.2,
    seed=42,
    item_tfms=train_transforms,
    batch_tfms=None,
    bs=batch_size,
    size=img_size
)
# Out:
# Could not do one pass in your dataloader, there is something wrong in it. Please see the stack trace below:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[19], line 1
# ----> 1 train_data = ImageDataLoaders.from_folder(
#       2     df,
#       3     valid_pct=0.2,
#       4     seed=42,
#       5     item_tfms=train_transforms,
#       6     batch_tfms=None,
#       7     bs=batch_size,
#       8     size=img_size
#       9 )
#
# File /opt/conda/lib/python3.10/site-packages/fastai/vision/data.py:123, in ImageDataLoaders.from_folder(cls, path, train, valid, valid_pct, seed, vocab, item_tfms, batch_tfms, img_cls, **kwargs)
#     116 get_items = get_image_files if valid_pct else partial(get_image_files, folders=[train, valid])
#     117 dblock = DataBlock(blocks=(ImageBlock(img_cls), CategoryBlock(vocab=vocab)),
#     118                    get_items=get_items,
# ...
